# %%
from loadData import loadData
import pandas as pd
import numpy as np
import math
import time
import datetime
import pdb
import copy
import scipy.spatial.distance as distance
import matplotlib.pyplot as plt
import itertools

def getDis(x1,y1,x2,y2):
    a=x1-x2
    b=y1-y2
    return math.sqrt(a**2+b**2)

def getAppropriateOrders(ori,dest,choiceSet):
    global orders,sites,locations
    filterAngle=30.0
    #print ori,dest
    thisX=sites.loc[ori,'x']
    thisY=sites.loc[ori,'y']
    xTo=locations.loc[dest,'x']
    yTo=locations.loc[dest,'y']
    choiceX=choiceSet.dx
    choiceY=choiceSet.dy
    a=distance.cdist([[thisX,thisY]],[[xTo,yTo]],'euclidean')
    b=distance.cdist([(thisX,thisY)],zip(choiceX,choiceY),'euclidean')
    c=distance.cdist([(xTo,yTo)],zip(choiceX,choiceY),'euclidean')
    ab=a[0]*b[0]
    a= a[0]**2
    b= b[0]**2
    c= c[0]**2
    angle=np.degrees(np.arccos((a+b-c)/2/ab))
    return list(choiceSet.index[angle<filterAngle])
    
    #a=plt.figure()
    #ax=a.add_subplot(111,aspect=1)
    #ax.scatter([thisX],[thisY],marker='^',s=100)
    #choiceX.index=range(len(choiceX))
    #ax.scatter(choiceX,choiceY,marker='s')
    #ax.scatter([xTo],[yTo],marker='o',s=100)
    #for i in range(len(choiceX)):
    #    ax.annotate(i,(choiceX[i],choiceY[i]))
    #plt.show()
    
def getAppropriateSites(ori,dest):
    global orders,sites
    global filterAngle
    #print ori,dest
    thisX=sites.loc[ori,'x']
    thisY=sites.loc[ori,'y']
    xTo=locations.loc[dest,'x']
    yTo=locations.loc[dest,'y']
    choiceX=sites.x
    choiceY=sites.y
    a=distance.cdist([[thisX,thisY]],[[xTo,yTo]],'euclidean')
    b=distance.cdist([(thisX,thisY)],zip(choiceX,choiceY),'euclidean')
    c=distance.cdist([(xTo,yTo)],zip(choiceX,choiceY),'euclidean')
    ab=a[0]*b[0]
    a= a[0]**2
    b= b[0]**2
    c= c[0]**2
    angle=np.degrees(np.arccos((a+b-c)/2/ab))
    return list(sites.index[(angle<filterAngle)&(b<a)])

def getDest(orderList):
    global orders
    dest=[orders.loc[i,'dest_id'] for i in orderList]
    return dest

def getShortestPath(startNode,nodesToVisit):
    global locations
    if len(nodesToVisit)==0:
        return ([],0,0)
    allNodes=[startNode]+nodesToVisit
    nodeX=locations.loc[allNodes,'x']
    nodeY=locations.loc[allNodes,'y']
    dis=distance.cdist(zip(nodeX,nodeY),zip(nodeX,nodeY),'euclidean')
    
    a=range(1,len(nodesToVisit)+1)
    permu=[]
    permu+=itertools.permutations(a,len(a))
    
    minDis=10**8
    minPermu=[]
    for i in permu:
        t=[0]+list(i)
        thisDis=0
        for j in range(1,len(t)):
            thisDis=thisDis+dis[t[j-1],t[j]]
        if thisDis<minDis:
            minDis=thisDis
            minPermu=t
    
    tmp=np.array(nodesToVisit)
    idx=np.array(minPermu[1:])-1
    return (tmp[idx],minDis,dis[minPermu[0],minPermu[1]])
    
    
    #fig=plt.figure()
    #ax=fig.add_subplot(111,aspect=1)
    #ax.scatter(nodeX,nodeY)
    #for i in range(len(nodeX)):
    #    ax.annotate(i,(nodeX[i],nodeY[i]))
    #plt.show()
    
def getPossibleSite(currentLoc,routeHistory):
    global  sites,locations
    global siteSearchRange
    
    currentX=locations.loc[currentLoc,'x']
    currentY=locations.loc[currentLoc,'y']
    otherSites=list(set(sites.index)-set(routeHistory)-set([currentLoc]))
    otherX=sites.loc[otherSites,'x']
    otherY=sites.loc[otherSites,'y']
    dis=distance.cdist([(currentX,currentY)],zip(otherX,otherY),'euclidean')
    minIndex=int(np.argmin(dis,axis=1))

    minDis= dis[0,minIndex]
    if minDis<siteSearchRange:
        return otherSites[minIndex]
    else:
        return 0
    
    

def getNext(currentLoad,ordersOnBoard,disTravelled,timeElasped,waitingTime,latePenalty,currentLoc,nodesToGo,orderHistory,routeHistory,timeHistory,depth):
    global maxLoad
    global maxSearchDis
    global locations, orders
    global spots,shops,sites
    global resultsNodes,resultsTime
    maxDepth=6
    SPEED=250 #meters per minute
    
    #if depth>maxDepth:
    #    return
    
    ordersOnBoard=copy.deepcopy(ordersOnBoard)
    orderHistory=copy.deepcopy(orderHistory)
    routeHistory=copy.deepcopy(routeHistory)
    timeHistory=copy.deepcopy(timeHistory)
    
    pre=str(depth)+'  '+'-'*(depth+1)
    print '%sload:%d, orders on board: %s, time elasped: %.1f, nodes visited: %s'%(pre,currentLoad,'/'.join(ordersOnBoard),timeElasped, '|'.join(routeHistory))
    print '%stime history:'%(pre),timeHistory
    print '%scurrently at: %s, nodesToGo: %s'%(pre,currentLoc,'|'.join(nodesToGo))
    routeHistory=routeHistory+[currentLoc]
    
    #if currentLoc is a site, then try to carry up all the appropriate orders.
    if depth==0:
        currentDest=orders.loc[ordersOnBoard[0],'dest_id']
    else:
        if len(nodesToGo)==0:
            (currentRoute,routeLength,nextStopDis)=getShortestPath(currentLoc,getDest(ordersOnBoard))
            if len(currentRoute)==0:
                #if locations.loc[currentLoc,'location_type']!='sites':
                print '%sno more orders to deliver. record and return.'%(pre)
                #record results, which we can then combine later.
                resultsNodes.append(routeHistory)
                resultsTime.append(timeHistory+[(timeElasped,timeElasped,[])])
                return 
            else:
                currentDest=currentRoute[0]
        else:
            currentDest=nodesToGo[0]
            
    
    if locations.loc[currentLoc,'location_type']=='sites':
        ordersOnThisSite=orders[orders['ori_id']==currentLoc]
        if len(ordersOnBoard)==0:#this means, during our delivery process, we finished all the delivery task and arrived at a new site.
            #we need to start all over. 
            #but, start all over will consume too much calculation. we can skip this and combine short results later.
            #just like the group method in didi project.
            
            #for k in ordersOnThisSite.index:
            #    currentLoad+=orders.loc[k,'num']
            #    ordersOnBoard=ordersOnBoard+[k]
            #    orderHistory=orderHistory+[k]
            #    print '%sempty bag, adding new order %s on this site.'%(pre,k)
            #    getNext(currentLoad,ordersOnBoard,disTravelled,timeElasped,waitingTime,latePenalty,currentLoc,nodesToGo,orderHistory,routeHistory,timeHistory,depth)
            pass
        else:
            ordersToCarry=set(getAppropriateOrders(currentLoc,currentDest,ordersOnThisSite))-set(ordersOnBoard)-set(orderHistory)
            print '%scurrently at a site. '%(pre)
            if len(ordersToCarry)==0:
                print '%sno orders available to carry. This search goes unecessary distance, abondaned.'%(pre)
                return
            print '%smore orders are available to carry: %s'%(pre, '/'.join(ordersToCarry))
            combo=[]
            for i in range(len(ordersToCarry)):
                combo+=itertools.combinations(ordersToCarry,i)
            for i in combo:
                t=list(i)
                
                #if we are at a site, we must fetch sth unless we are at the first depth.
                if depth>0 and len(t)==0:
                    continue
                tmpSum=0
                for j in t:
                    tmpSum+=orders.loc[j,'num']
                if tmpSum+currentLoad<maxLoad:
                    currentLoad+=tmpSum
                    ordersOnBoard=ordersOnBoard+t
                    orderHistory=orderHistory+t
                    print  '%spicking up orders: [%s], new load: %d'%(pre,'/'.join(t),currentLoad)
                    (currentRoute,routeLength,nextStopDis)=getShortestPath(currentLoc,getDest(ordersOnBoard))
                    currentDest=currentRoute[0]
                    if len(currentRoute)>1:
                        nodesToGo=currentRoute[1:]
                    else:
                        nodesToGo=[]
                    print '%snew route: %s, route length: %.1f'%(pre,'->'.join(currentRoute),routeLength)
                    print '%smoving to: %s'%(pre,currentDest)
                    timeElaspedWithoutNewSites=timeElasped+nextStopDis/SPEED
                    #routeHistoryWithoutNewSites=routeHistory+[currentDest]
                    #timeHistoryWithoutNewSites=timeHistory+[(timeElasped,timeElasped)]
                    disTravelledWithoutNewSites=disTravelled+nextStopDis
                    if depth==0:
                        timeHistoryThis=timeHistory+[(timeElasped,timeElasped,ordersOnBoard,'pickup')]
                    else:
                        timeHistoryThis=timeHistory+[(timeElasped,timeElasped,t,'pickup')]
                    getNext(currentLoad,ordersOnBoard,disTravelledWithoutNewSites,timeElaspedWithoutNewSites,waitingTime,latePenalty,currentDest,nodesToGo,orderHistory,routeHistory,timeHistoryThis,depth+1)


                    #try to see if this rider can visit ONE other site before serving orders.
                    #at present, very simple rule: go to the nearest unvisited site.
                    #sitesToVisit=set(getAppropriateSites(currentLoc,currentDest))-set(routeHistory)
                    siteToVisit=getPossibleSite(currentLoc,routeHistory)
                    if siteToVisit==0 or currentLoad>100:
                        print '%sno nearby unvisited sites or bag almost full(%d).'%(pre,currentLoad)
                        continue

                    print '%smoving to sites %s, trying to collect more pacakges.'%(pre,siteToVisit)                
                    currentDest=siteToVisit
                    dis=getDis(locations.loc[currentLoc,'x'],locations.loc[currentLoc,'y'],locations.loc[currentDest,'x'],locations.loc[currentDest,'y'])
                    timeElaspedWithNewSites=timeElasped+ dis/SPEED
                    #routeHistoryWithNewSites=routeHistory+[currentDest]
                    #timeHistoryWithNewSites=timeHistory+[(timeElasped,timeElasped)]
                    disTravelledWithNewSites=disTravelled+dis
                    getNext(currentLoad,ordersOnBoard,disTravelledWithNewSites,timeElaspedWithNewSites,waitingTime,latePenalty,currentDest,[],orderHistory,routeHistory,timeHistoryThis,depth+1)


    elif locations.loc[currentLoc,'location_type']=='spots':
                   
        arrivalTime=timeElasped
        timeNeeded=0
        
        for o in ordersOnBoard:
            if orders.loc[o,'dest_id']==currentLoc:
                newlyHandled=[o]
                num=orders.loc[o,'num']
                currentLoad-=num
                timeNeeded=3*math.sqrt(num)+5
                timeElasped+=timeNeeded
                ordersOnBoard.remove(o)
                print '%sOrder %s delivered, time consumed: %.1f, remaining load: %d'%(pre,o,timeNeeded,currentLoad)
                break
        assert timeNeeded>0
        departureTime=timeElasped
        timeHistory=timeHistory+[(arrivalTime,departureTime,newlyHandled,'deliver')]
        #nodesToGo.remove(currentLoc)
        #timeHistory=timeHistory+[timeElasped]
        #go to the next spot directly (copy the code of sites handling)
        if len(nodesToGo)>0:
            currentDest=nodesToGo[0]
            nodesToGo=np.delete(nodesToGo,[0])
            print '%smoving to: %s'%(pre,currentDest)
            nextStopDis=getDis(locations.loc[currentLoc,'x'],locations.loc[currentLoc,'y'],locations.loc[currentDest,'x'],locations.loc[currentDest,'y'])
            timeElaspedWithoutNewSites=timeElasped+nextStopDis/SPEED
            #routeHistoryWithoutNewSites=routeHistory+[currentDest]
            #timeHistoryWithoutNewSites=timeHistory+[(arrivalTime,departureTime)]
            disTravelledWithoutNewSites=disTravelled+nextStopDis
            getNext(currentLoad,ordersOnBoard,disTravelledWithoutNewSites,timeElaspedWithoutNewSites,waitingTime,latePenalty,currentDest,nodesToGo,orderHistory,routeHistory,timeHistory,depth+1)
        else:
            print '%sno more nodes to go'%(pre)
        
        if depth<maxDepth:
            #go to the nearest sites if the search is not too deep. otherwise, stop going deeper and devliver all the goods
            #so that we get a result to record.
            siteToVisit=getPossibleSite(currentLoc,routeHistory)
            if siteToVisit==0 or currentLoad>100:
                print '%sno nearby unvisited sites or bag almost full(%d).'%(pre,currentLoad)
            else:
                print '%smoving to sites %s, trying to collect more pacakges.'%(pre,siteToVisit)                
                currentDest=siteToVisit
                dis=getDis(locations.loc[currentLoc,'x'],locations.loc[currentLoc,'y'],locations.loc[currentDest,'x'],locations.loc[currentDest,'y'])
                timeElaspedWithNewSites=timeElasped+ dis/SPEED
                #routeHistoryWithNewSites=routeHistory+[currentDest]
                #timeHistoryWithNewSites=timeHistory+[(arrivalTime,departureTime)]
                disTravelledWithNewSites=disTravelled+dis
                getNext(currentLoad,ordersOnBoard,disTravelledWithNewSites,timeElaspedWithNewSites,waitingTime,latePenalty,currentDest,[],orderHistory,routeHistory,timeHistory,depth+1)


def search(normalOrderToStart):
    global startTime
    global locations,orders
    global maxLoad
    print 'search for %s started at time %.1f'%(normalOrderToStart,time.time()-startTime)
    thisLoad=orders.loc[normalOrderToStart,'num']
    thisLoc=orders.loc[normalOrderToStart,'ori_id']
    getNext(thisLoad,[normalOrderToStart],0,0,0,0,thisLoc,[],[normalOrderToStart],[],[],0)

# %%
maxLoad=140
terminateTime=12*60.0
filterAngle=30.0
siteSearchRange=2000 #only search sites within 5km
startTime=time.time()
(locations,orders)=loadData('../original_data')
sites=locations[locations['location_type']=='sites']
shops=locations[locations['location_type']=='shops']
spots=locations[locations['location_type']=='spots']

numOfSites=len(sites)
numOfOrders=len(orders)
normalOrders=orders[orders['order_type']==0]
numOfNormalOrders=len(normalOrders)
print 'data set has %d orders, of which %d are normal orders.'%(numOfOrders,numOfNormalOrders)
# Out:
# loading data...
# load complted.
# data set has 12487 orders, of which 9214 are normal orders.

# %%
resultsNodes=[]
resultsTime=[]
search(normalOrders.index[10])
# Out:
# search for F0011 started at time 72.9
# 0  -load:58, orders on board: F0011, time elasped: 0.0, nodes visited:
# 0  -time history: []
# 0  -currently at: A001, nodesToGo:
# 0  -currently at a site.
# 0  -more orders are available to carry: F0010/F0007/F0006
# 0  -picking up orders: [], new load: 58
# 0  -new route: B8121, route length: 702.3
# 0  -moving to: B8121
# 1  --load:58, orders on board: F0011, time elasped: 2.8, nodes visited: A001
# 1  --time history: [(0, 0, ['F0011'], 'pickup')]
# 1  --currently at: B8121, nodesToGo:
# 1  --Order F0011 delivered, time consumed: 27.8, remaining load: 0
# 1  --no more nodes to go
# 1  --moving to sites A122, trying to collect more pacakges.
# 2  ---load:0, orders on board: , time elasped: 34.4, nodes visited: A001|B8121
# 2  ---time history: [(0, 0, ['F0011'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver')]
# 2  ---currently at: A122, nodesToGo:
# 2  ---no more orders to deliver. record and return.
# 0  -moving to sites A118, trying to collect more pacakges.
# 1  --load:58, orders on board: F0011, time elasped: 3.0, nodes visited: A001
# 1  --time history: [(0, 0, ['F0011'], 'pickup')]
# 1  --currently at: A118, nodesToGo:
# 1  --currently at a site.
# 1  --no orders available to carry. This search goes unecessary distance, abondaned.
# 0  -picking up orders: [F0010], new load: 88
# 0  -new route: B7888->B8121, route length: 983.8
# 0  -moving to: B7888
# 1  --load:88, orders on board: F0011/F0010, time elasped: 2.8, nodes visited: A001
# 1  --time history: [(0, 0, ['F0011', 'F0010'], 'pickup')]
# 1  --currently at: B7888, nodesToGo: B8121
# 1  --Order F0010 delivered, time consumed: 21.4, remaining load: 58
# 1  --moving to: B8121
# 2  ---load:58, orders on board: F0011, time elasped: 25.4, nodes visited: A001|B7888
# 2  ---time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.7876732616997262, 24.219349986854709, ['F0010'], 'deliver')]
# 2  ---currently at: B8121, nodesToGo:
# 2  ---Order F0011 delivered, time consumed: 27.8, remaining load: 0
# 2  ---no more nodes to go
# 2  ---moving to sites A122, trying to collect more pacakges.
# 3  ----load:0, orders on board: , time elasped: 57.0, nodes visited: A001|B7888|B8121
# 3  ----time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.7876732616997262, 24.219349986854709, ['F0010'], 'deliver'), (25.367055026096217, 53.214374343687943, ['F0011'], 'deliver')]
# 3  ----currently at: A122, nodesToGo:
# 3  ----no more orders to deliver. record and return.
# 1  --moving to sites A118, trying to collect more pacakges.
# 2  ---load:58, orders on board: F0011, time elasped: 27.3, nodes visited: A001|B7888
# 2  ---time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.7876732616997262, 24.219349986854709, ['F0010'], 'deliver')]
# 2  ---currently at: A118, nodesToGo:
# 2  ---currently at a site.
# 2  ---no orders available to carry. This search goes unecessary distance, abondaned.
# 0  -moving to sites A118, trying to collect more pacakges.
# 1  --load:88, orders on board: F0011/F0010, time elasped: 3.0, nodes visited: A001
# 1  --time history: [(0, 0, ['F0011', 'F0010'], 'pickup')]
# 1  --currently at: A118, nodesToGo:
# 1  --currently at a site.
# 1  --more orders are available to carry: F8847/F8827
# 1  --picking up orders: [F8847], new load: 137
# 1  --new route: B7888->B8121->B8910, route length: 1706.9
# 1  --moving to: B7888
# 2  ---load:137, orders on board: F0011/F0010/F8847, time elasped: 6.0, nodes visited: A001|A118
# 2  ---time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup')]
# 2  ---currently at: B7888, nodesToGo: B8121|B8910
# 2  ---Order F0010 delivered, time consumed: 21.4, remaining load: 107
# 2  ---moving to: B8121
# 3  ----load:107, orders on board: F0011/F8847, time elasped: 28.6, nodes visited: A001|A118|B7888
# 3  ----time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver')]
# 3  ----currently at: B8121, nodesToGo: B8910
# 3  ----Order F0011 delivered, time consumed: 27.8, remaining load: 49
# 3  ----moving to: B8910
# 4  -----load:49, orders on board: F8847, time elasped: 59.1, nodes visited: A001|A118|B7888|B8121
# 4  -----time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver')]
# 4  -----currently at: B8910, nodesToGo:
# 4  -----Order F8847 delivered, time consumed: 26.0, remaining load: 0
# 4  -----no more nodes to go
# 4  -----moving to sites A122, trying to collect more pacakges.
# 5  ------load:0, orders on board: , time elasped: 90.5, nodes visited: A001|A118|B7888|B8121|B8910
# 5  ------time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (59.067898334666474, 85.067898334666467, ['F8847'], 'deliver')]
# 5  ------currently at: A122, nodesToGo:
# 5  ------no more orders to deliver. record and return.
# 3  ----moving to sites A122, trying to collect more pacakges.
# 4  -----load:49, orders on board: F8847, time elasped: 60.2, nodes visited: A001|A118|B7888|B8121
# 4  -----time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver')]
# 4  -----currently at: A122, nodesToGo:
# 4  -----currently at a site.
# 4  -----more orders are available to carry: F9040/F9057/F9055/F9047/F9048/F9059/F9039/F9065
# 4  -----picking up orders: [F9040], new load: 107
# 4  -----new route: B1318->B8910, route length: 1379.5
# 4  -----moving to: B1318
# 5  ------load:107, orders on board: F8847/F9040, time elasped: 62.9, nodes visited: A001|A118|B7888|B8121|A122
# 5  ------time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (60.221762056957999, 60.221762056957999, ['F9040'], 'pickup')]
# 5  ------currently at: B1318, nodesToGo: B8910
# 5  ------Order F9040 delivered, time consumed: 27.8, remaining load: 49
# 5  ------moving to: B8910
# 6  -------load:49, orders on board: F8847, time elasped: 93.6, nodes visited: A001|A118|B7888|B8121|A122|B1318
# 6  -------time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (60.221762056957999, 60.221762056957999, ['F9040'], 'pickup'), (62.863661621973321, 90.710980939565047, ['F9040'], 'deliver')]
# 6  -------currently at: B8910, nodesToGo:
# 6  -------Order F8847 delivered, time consumed: 26.0, remaining load: 0
# 6  -------no more nodes to go
# 5  ------moving to sites A040, trying to collect more pacakges.
# 6  -------load:49, orders on board: F8847, time elasped: 97.2, nodes visited: A001|A118|B7888|B8121|A122|B1318
# 6  -------time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (60.221762056957999, 60.221762056957999, ['F9040'], 'pickup'), (62.863661621973321, 90.710980939565047, ['F9040'], 'deliver')]
# 6  -------currently at: A040, nodesToGo:
# 6  -------currently at a site.
# 6  -------more orders are available to carry: F3688/F3667/F3679
# 6  -------picking up orders: [F3688], new load: 91
# 6  -------new route: B5646->B8910, route length: 2257.4
# 6  -------moving to: B5646
# 7  --------load:91, orders on board: F8847/F3688, time elasped: 98.8, nodes visited: A001|A118|B7888|B8121|A122|B1318|A040
# 7  --------time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (60.221762056957999, 60.221762056957999, ['F9040'], 'pickup'), (62.863661621973321, 90.710980939565047, ['F9040'], 'deliver'), (97.164449931744855, 97.164449931744855, ['F3688'], 'pickup')]
# 7  --------currently at: B5646, nodesToGo: B8910
# 7  --------Order F3688 delivered, time consumed: 24.4, remaining load: 49
# 7  --------moving to: B8910
# 8  ---------load:49, orders on board: F8847, time elasped: 130.6, nodes visited: A001|A118|B7888|B8121|A122|B1318|A040|B5646
# 9  ----------time history: [(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (60.221762056957999, 60.221762056957999, ['F9040'], 'pickup'), (62.863661621973321, 90.710980939565047, ['F9040'], 'deliver'), (97.164449931744855, 97.164449931744855, ['F3667'], 'pickup'), (98.824881239921098, 123.26710333514468, ['F3688'], 'deliver'), (124.16779879340461, 148.37717150570316, ['F3667'], 'deliver')]
# 9  ----------currently at: B8910, nodesToGo:
# 9  ----------Order F8847 delivered, time consumed: 26.0, remaining load: 0
# 9  ----------no more nodes to go
# 6  -------no nearby unvisited sites or bag almost full(132).
# 4  -----no nearby unvisited sites or bag almost full(107).
# 2  ---no nearby unvisited sites or bag almost full(107).
# 1  --no nearby unvisited sites or bag almost full(137).
# 0  -picking up orders: [F0006], new load: 139
# 0  -new route: B8121->B7888->B3858, route length: 1463.8
# 0  -moving to: B8121
# 1  --load:139, orders on board: F0011/F0010/F0006, time elasped: 2.8, nodes visited: A001
# 1  --time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup')]
# 1  --currently at: B8121, nodesToGo: B7888|B3858
# 1  --Order F0011 delivered, time consumed: 27.8, remaining load: 81
# 1  --moving to: B7888
# 2  ---load:81, orders on board: F0010/F0006, time elasped: 31.8, nodes visited: A001|B8121
# 2  ---time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver')]
# 2  ---currently at: B7888, nodesToGo: B3858
# 2  ---Order F0010 delivered, time consumed: 21.4, remaining load: 51
# 2  ---moving to: B3858
# 3  ----load:51, orders on board: F0006, time elasped: 55.1, nodes visited: A001|B8121|B7888
# 3  ----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver')]
# 3  ----currently at: B3858, nodesToGo:
# 3  ----Order F0006 delivered, time consumed: 26.4, remaining load: 0
# 3  ----no more nodes to go
# 3  ----moving to sites A122, trying to collect more pacakges.
# 4  -----load:0, orders on board: , time elasped: 85.9, nodes visited: A001|B8121|B7888|B3858
# 4  -----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (55.134171689985358, 81.558456975613908, ['F0006'], 'deliver')]
# 4  -----currently at: A122, nodesToGo:
# 4  -----no more orders to deliver. record and return.
# 2  ---moving to sites A118, trying to collect more pacakges.
# 3  ----load:51, orders on board: F0006, time elasped: 56.3, nodes visited: A001|B8121|B7888
# 3  ----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver')]
# 3  ----currently at: A118, nodesToGo:
# 3  ----currently at a site.
# 3  ----more orders are available to carry: F8825/F8837/F8827/F8847
# 3  ----picking up orders: [F8825], new load: 87
# 3  ----new route: B1627->B3858, route length: 1276.3
# 3  ----moving to: B1627
# 4  -----load:87, orders on board: F0006/F8825, time elasped: 59.7, nodes visited: A001|B8121|B7888|A118
# 4  -----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup')]
# 4  -----currently at: B1627, nodesToGo: B3858
# 4  -----Order F8825 delivered, time consumed: 23.0, remaining load: 51
# 4  -----moving to: B3858
# 5  ------load:51, orders on board: F0006, time elasped: 84.4, nodes visited: A001|B8121|B7888|A118|B1627
# 5  ------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver')]
# 5  ------currently at: B3858, nodesToGo:
# 5  ------Order F0006 delivered, time consumed: 26.4, remaining load: 0
# 5  ------no more nodes to go
# 5  ------moving to sites A122, trying to collect more pacakges.
# 6  -------load:0, orders on board: , time elasped: 115.2, nodes visited: A001|B8121|B7888|A118|B1627|B3858
# 6  -------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver'), (84.382896927448343, 110.80718221307689, ['F0006'], 'deliver')]
# 6  -------currently at: A122, nodesToGo:
# 6  -------no more orders to deliver. record and return.
# 4  -----moving to sites A122, trying to collect more pacakges.
# 5  ------load:51, orders on board: F0006, time elasped: 88.6, nodes visited: A001|B8121|B7888|A118|B1627
# 5  ------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver')]
# 5  ------currently at: A122, nodesToGo:
# 5  ------currently at a site.
# 5  ------more orders are available to carry: F9040/F9057/F9055/F9047/F9048/F9059/F9039/F9065
# 5  ------picking up orders: [F9040], new load: 109
# 5  ------new route: B1318->B3858, route length: 1127.2
# 5  ------moving to: B1318
# 6  -------load:109, orders on board: F0006/F9040, time elasped: 91.2, nodes visited: A001|B8121|B7888|A118|B1627|A122
# 6  -------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver'), (88.592224822229795, 88.592224822229795, ['F9040'], 'pickup')]
# 6  -------currently at: B1318, nodesToGo: B3858
# 6  -------Order F9040 delivered, time consumed: 27.8, remaining load: 51
# 6  -------moving to: B3858
# 7  --------load:51, orders on board: F0006, time elasped: 120.9, nodes visited: A001|B8121|B7888|A118|B1627|A122|B1318
# 7  --------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver'), (88.592224822229795, 88.592224822229795, ['F9040'], 'pickup'), (91.234124387245117, 119.08144370483684, ['F9040'], 'deliver')]
# 7  --------currently at: B3858, nodesToGo:
# 7  --------Order F0006 delivered, time consumed: 26.4, remaining load: 0
# 7  --------no more nodes to go
# 5  ------no nearby unvisited sites or bag almost full(109).
# 3  ----moving to sites A084, trying to collect more pacakges.
# 4  -----load:87, orders on board: F0006/F8825, time elasped: 59.8, nodes visited: A001|B8121|B7888|A118
# 4  -----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup')]
# 4  -----currently at: A084, nodesToGo:
# 4  -----currently at a site.
# 4  -----more orders are available to carry: F6387
# 3  ----picking up orders: [F8837], new load: 135
# 3  ----new route: B1627->B5078->B3858, route length: 1718.1
# 3  ----moving to: B1627
# 4  -----load:135, orders on board: F0006/F8825/F8837, time elasped: 59.7, nodes visited: A001|B8121|B7888|A118
# 4  -----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8837'], 'pickup')]
# 4  -----currently at: B1627, nodesToGo: B5078|B3858
# 4  -----Order F8825 delivered, time consumed: 23.0, remaining load: 99
# 4  -----moving to: B5078
# 5  ------load:99, orders on board: F0006/F8837, time elasped: 83.9, nodes visited: A001|B8121|B7888|A118|B1627
# 5  ------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8837'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver')]
# 5  ------currently at: B5078, nodesToGo: B3858
# 5  ------Order F8837 delivered, time consumed: 25.8, remaining load: 51
# 5  ------moving to: B3858
# 6  -------load:51, orders on board: F0006, time elasped: 111.9, nodes visited: A001|B8121|B7888|A118|B1627|B5078
# 1  --moving to sites A122, trying to collect more pacakges.
# 2  ---load:81, orders on board: F0010/F0006, time elasped: 34.4, nodes visited: A001|B8121
# 2  ---time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver')]
# 2  ---currently at: A122, nodesToGo:
# 2  ---currently at a site.
# 2  ---more orders are available to carry: F9040/F9057/F9055/F9047/F9048/F9059/F9039/F9065
# 2  ---picking up orders: [F9040], new load: 139
# 2  ---new route: B1318->B3858->B7888, route length: 1601.7
# 2  ---moving to: B1318
# 3  ----load:139, orders on board: F0010/F0006/F9040, time elasped: 37.1, nodes visited: A001|B8121|A122
# 3  ----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup')]
# 3  ----currently at: B1318, nodesToGo: B3858|B7888
# 3  ----Order F9040 delivered, time consumed: 27.8, remaining load: 81
# 3  ----moving to: B3858
# 4  -----load:81, orders on board: F0010/F0006, time elasped: 66.8, nodes visited: A001|B8121|A122|B1318
# 4  -----time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver')]
# 4  -----currently at: B3858, nodesToGo: B7888
# 4  -----Order F0006 delivered, time consumed: 26.4, remaining load: 30
# 4  -----moving to: B7888
# 5  ------load:30, orders on board: F0010, time elasped: 95.1, nodes visited: A001|B8121|A122|B1318|B3858
# 5  ------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver')]
# 5  ------currently at: B7888, nodesToGo:
# 5  ------Order F0010 delivered, time consumed: 21.4, remaining load: 0
# 5  ------no more nodes to go
# 5  ------moving to sites A118, trying to collect more pacakges.
# 6  -------load:0, orders on board: , time elasped: 119.6, nodes visited: A001|B8121|A122|B1318|B3858|B7888
# 6  -------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (95.127216110960092, 116.55889283611508, ['F0010'], 'deliver')]
# 6  -------currently at: A118, nodesToGo:
# 6  -------no more orders to deliver. record and return.
# 4  -----moving to sites A118, trying to collect more pacakges.
# 5  ------load:30, orders on board: F0010, time elasped: 97.9, nodes visited: A001|B8121|A122|B1318|B3858
# 5  ------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver')]
# 5  ------currently at: A118, nodesToGo:
# 5  ------currently at a site.
# 5  ------more orders are available to carry: F8847/F8827
# 5  ------picking up orders: [F8847], new load: 79
# 5  ------new route: B7888->B8910, route length: 1268.6
# 5  ------moving to: B7888
# 6  -------load:79, orders on board: F0010/F8847, time elasped: 101.0, nodes visited: A001|B8121|A122|B1318|B3858|A118
# 6  -------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (97.91371968089814, 97.91371968089814, ['F8847'], 'pickup')]
# 6  -------currently at: B7888, nodesToGo: B8910
# 6  -------Order F0010 delivered, time consumed: 21.4, remaining load: 49
# 6  -------moving to: B8910
# 7  --------load:49, orders on board: F8847, time elasped: 124.4, nodes visited: A001|B8121|A122|B1318|B3858|A118|B7888
# 7  --------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (97.91371968089814, 97.91371968089814, ['F8847'], 'pickup'), (100.95537294279819, 122.38704966795318, ['F0010'], 'deliver')]
# 7  --------currently at: B8910, nodesToGo:
# 7  --------Order F8847 delivered, time consumed: 26.0, remaining load: 0
# 7  --------no more nodes to go
# 5  ------moving to sites A084, trying to collect more pacakges.
# 6  -------load:79, orders on board: F0010/F8847, time elasped: 101.4, nodes visited: A001|B8121|A122|B1318|B3858|A118
# 6  -------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (97.91371968089814, 97.91371968089814, ['F8847'], 'pickup')]
# 6  -------currently at: A084, nodesToGo:
# 6  -------currently at a site.
# 6  -------more orders are available to carry: F6386/F6387
# 6  -------picking up orders: [F6386], new load: 98
# 6  -------new route: B7279->B7888->B8910, route length: 2151.7
# 6  -------moving to: B7279
# 7  --------load:98, orders on board: F0010/F8847/F6386, time elasped: 102.9, nodes visited: A001|B8121|A122|B1318|B3858|A118|A084
# 10  -----------currently at: B8910, nodesToGo:
# 10  -----------Order F8847 delivered, time consumed: 26.0, remaining load: 0
# 10  -----------no more nodes to go
# 6  -------no nearby unvisited sites or bag almost full(116).
# 5  ------picking up orders: [F8827], new load: 121
# 5  ------new route: B2378->B7888->B8910, route length: 1417.3
# 5  ------moving to: B2378
# 6  -------load:121, orders on board: F0010/F8847/F8827, time elasped: 100.0, nodes visited: A001|B8121|A122|B1318|B3858|A118
# 6  -------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (97.91371968089814, 97.91371968089814, ['F8827'], 'pickup')]
# 6  -------currently at: B2378, nodesToGo: B7888|B8910
# 6  -------Order F8827 delivered, time consumed: 24.4, remaining load: 79
# 6  -------moving to: B7888
# 7  --------load:79, orders on board: F0010/F8847, time elasped: 126.0, nodes visited: A001|B8121|A122|B1318|B3858|A118|B2378
# 7  --------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (97.91371968089814, 97.91371968089814, ['F8827'], 'pickup'), (99.9662636726286, 124.40848576785218, ['F8827'], 'deliver')]
# 7  --------currently at: B7888, nodesToGo: B8910
# 7  --------Order F0010 delivered, time consumed: 21.4, remaining load: 49
# 7  --------moving to: B8910
# 8  ---------load:49, orders on board: F8847, time elasped: 149.5, nodes visited: A001|B8121|A122|B1318|B3858|A118|B2378|B7888
# 8  ---------time history: [(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (97.91371968089814, 97.91371968089814, ['F8827'], 'pickup'), (99.9662636726286, 124.40848576785218, ['F8827'], 'deliver'), (125.99249684593123, 147.42417357108621, ['F0010'], 'deliver')]
# 8  ---------currently at: B8910, nodesToGo:
# 8  ---------Order F8847 delivered, time consumed: 26.0, remaining load: 0
# 8  ---------no more nodes to go
# 5  ------no nearby unvisited sites or bag almost full(121).
# 3  ----moving to sites A118, trying to collect more pacakges.
# 4  -----load:81, orders on board: F0010/F0006, time elasped: 70.3, nodes visited: A001|B8121|A122|B1318
# 6  -------currently at: A073, nodesToGo:
# 6  -------currently at a site.
# 6  -------no orders available to carry. This search goes unecessary distance, abondaned.
# 4  -----no nearby unvisited sites or bag almost full(130).
# 2  ---no nearby unvisited sites or bag almost full(139).
# 0  -no nearby unvisited sites or bag almost full(139).

# %%
for i in range(len(resultsNodes)):
    print '\n---results no.',i,'---'
    print 'node sequence:\n\t',resultsNodes[i],'\ntimes:\n\t',resultsTime[i]
# Out:
# ---results no. 0 ---
# node sequence:
# 	['A001', 'B8121', 'A122']
# times:
# 	[(0, 0, ['F0011'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, [])]
#
# ---results no. 1 ---
# node sequence:
# 	['A001', 'B7888', 'B8121', 'A122']
# times:
# 	[(0, 0, ['F0011', 'F0010'], 'pickup'), (2.7876732616997262, 24.219349986854709, ['F0010'], 'deliver'), (25.367055026096217, 53.214374343687943, ['F0011'], 'deliver'), (57.006528160421254, 57.006528160421254, [])]
#
# ---results no. 2 ---
# node sequence:
# 	['A001', 'A118', 'B7888', 'B8121', 'B8910', 'A122']
# times:
# 	[(0, 0, ['F0011', 'F0010'], 'pickup'), (2.9612538963364123, 2.9612538963364123, ['F8847'], 'pickup'), (6.0029071582364715, 27.434583883391454, ['F0010'], 'deliver'), (28.582288922632962, 56.429608240224688, ['F0011'], 'deliver'), (59.067898334666474, 85.067898334666467, ['F8847'], 'deliver'), (90.486596014768267, 90.486596014768267, [])]
#
# ---results no. 3 ---
# node sequence:
# 	['A001', 'B8121', 'B7888', 'B3858', 'A122']
# times:
# 	[(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (55.134171689985358, 81.558456975613908, ['F0006'], 'deliver'), (85.922689482177347, 85.922689482177347, [])]
#
# ---results no. 4 ---
# node sequence:
# 	['A001', 'B8121', 'B7888', 'A118', 'B1627', 'B3858', 'A122']
# times:
# 	[(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (31.804322186654925, 53.235998911809908, ['F0010'], 'deliver'), (56.277652173709967, 56.277652173709967, ['F8825'], 'pickup'), (59.653037460082039, 82.653037460082032, ['F8825'], 'deliver'), (84.382896927448343, 110.80718221307689, ['F0006'], 'deliver'), (115.17141471964032, 115.17141471964032, [])]
#
# ---results no. 5 ---
# node sequence:
# 	['A001', 'B8121', 'A122', 'B1318', 'B3858', 'B7888', 'A118']
# times:
# 	[(0, 0, ['F0011', 'F0010', 'F0006'], 'pickup'), (2.8092978298216926, 30.656617147413417, ['F0011'], 'deliver'), (34.448770964146725, 34.448770964146725, ['F9040'], 'pickup'), (37.090670529162054, 64.93798984675378, ['F9040'], 'deliver'), (66.804758047156099, 93.229043332784642, ['F0006'], 'deliver'), (95.127216110960092, 116.55889283611508, ['F0010'], 'deliver'), (119.60054609801514, 119.60054609801514, [])]
